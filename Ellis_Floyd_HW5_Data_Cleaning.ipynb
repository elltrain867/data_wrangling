# %% [markdown]
# <a href="https://colab.research.google.com/github/elltrain867/data_wrangling/blob/main/Ellis_Floyd_HW5_Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import python packages
import pandas as pd
print("import package libraries")
# Out:
# import package libraries

# %%
# load dataset
tree_census = pd.read_csv('trees.csv')
print("load dataset may take long to load")
# Out:
# load dataset may take long to load

# %%
# look at the first five rows
tree_census.tail()
# Out:
#         created_at  tree_id block_id  \
# 424036  06/22/2016  597,947  334,923
# 424037  05/19/2016  562,201  315,842
# 424038  07/03/2016  613,191  348,289
# 424039  06/22/2016  597,415  315,182
# 424040  06/23/2016  599,887  601,873
#
#                                              the_geom  tree_dbh  stump_diam  \
# 424036  POINT (-73.73400725411123 40.726765747049605)       3.0         0.0
# 424037   POINT (-73.81178143224437 40.79141432315213)       2.0         0.0
# 424038   POINT (-73.84878694120046 40.71638163469394)       3.0         0.0
# 424039   POINT (-73.79857450847065 40.78709014372398)      11.0         0.0
# 424040                                    POINT (-73.       NaN         NaN
#
#        curb_loc status health          spc_latin  ... st_assem st_senate  \
# 424036   OnCurb  Alive   Good   Parrotia persica  ...     33.0      11.0
# 424037   OnCurb  Alive   Good  Quercus shumardii  ...     26.0      11.0
# 424038   OnCurb  Alive   Good         Cornus mas  ...     28.0      15.0
# 424039   OnCurb  Alive   Good         Cornus mas  ...     26.0      11.0
# 424040      NaN    NaN    NaN                NaN  ...      NaN       NaN
#
#          nta        nta_name    boro_ct     state   Latitude  longitude  \
# 424036  QN34  Queens Village  4056000.0  New York  40.726766 -73.734007
# 424037  QN49      Whitestone  4098700.0  New York  40.791414 -73.811781
# 424038  QN17    Forest Hills  4072300.0  New York  40.716382 -73.848787
# 424039  QN49      Whitestone  4099100.0  New York  40.787090 -73.798575
# 424040   NaN             NaN        NaN       NaN        NaN        NaN
#
#                    x_sp            y_sp
# 424036  1,057,974.96441  204,168.848274
# 424037  1,036,367.79798  227,666.497145
# 424038  1,026,168.15861  200,309.842212
# 424039  1,040,028.41697  226,099.187615
# 424040              NaN             NaN
#
# [5 rows x 42 columns]

# %%
# list of column names
tree_census.columns
# Out:
# Index(['created_at', 'tree_id', 'block_id', 'the_geom', 'tree_dbh',
#        'stump_diam', 'curb_loc', 'status', 'health', 'spc_latin', 'spc_common',
#        'steward', 'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
#        'root_grate', 'root_other', 'trnk_wire', 'trnk_light', 'trnk_other',
#        'brnch_ligh', 'brnch_shoe', 'brnch_othe', 'address', 'zipcode',
#        'zip_city', 'cb_num', 'borocode', 'boroname', 'cncldist', 'st_assem',
#        'st_senate', 'nta', 'nta_name', 'boro_ct', 'state', 'Latitude',
#        'longitude', 'x_sp', 'y_sp'],
#       dtype='object')

# %%
# identify the size, number of rows and columns in the dataset
tree_census.shape
# Out:
# (424041, 42)

# %%
# summary of the dataset
tree_census.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 424041 entries, 0 to 424040
# Data columns (total 42 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   created_at  424041 non-null  object
#  1   tree_id     424041 non-null  object
#  2   block_id    424041 non-null  object
#  3   the_geom    424041 non-null  object
#  4   tree_dbh    424040 non-null  float64
#  5   stump_diam  424040 non-null  float64
#  6   curb_loc    424040 non-null  object
#  7   status      424040 non-null  object
#  8   health      404362 non-null  object
#  9   spc_latin   404363 non-null  object
#  10  spc_common  404363 non-null  object
#  11  steward     95197 non-null   object
#  12  guards      44326 non-null   object
#  13  sidewalk    404362 non-null  object
#  14  user_type   424040 non-null  object
#  15  problems    131591 non-null  object
#  16  root_stone  424040 non-null  object
#  17  root_grate  424040 non-null  object
#  18  root_other  424040 non-null  object
#  19  trnk_wire   424040 non-null  object
#  20  trnk_light  424040 non-null  object
#  21  trnk_other  424040 non-null  object
#  22  brnch_ligh  424040 non-null  object
#  23  brnch_shoe  424040 non-null  object
#  24  brnch_othe  424040 non-null  object
#  25  address     424040 non-null  object
#  26  zipcode     424040 non-null  float64
#  27  zip_city    424040 non-null  object
#  28  cb_num      424040 non-null  float64
#  29  borocode    424040 non-null  float64
#  30  boroname    424040 non-null  object
#  31  cncldist    424040 non-null  float64
#  32  st_assem    424040 non-null  float64
#  33  st_senate   424040 non-null  float64
#  34  nta         424040 non-null  object
#  35  nta_name    424040 non-null  object
#  36  boro_ct     424040 non-null  float64
#  37  state       424040 non-null  object
#  38  Latitude    424040 non-null  float64
#  39  longitude   424040 non-null  float64
#  40  x_sp        424040 non-null  object
#  41  y_sp        424040 non-null  object
# dtypes: float64(11), object(31)
# memory usage: 135.9+ MB

# %%
# health status of trees
tree_census.health.value_counts(dropna=False)
# Out:
# health
# Good    330671
# Fair     56350
# NaN      19679
# Poor     17341
# Name: count, dtype: int64

# %%
# get status on the trees
tree_census.status.value_counts(dropna=False)
# Out:
# status
# Alive    404363
# Stump     11213
# Dead       8464
# NaN           1
# Name: count, dtype: int64

# %%
# subset of the original, removed columns not interested in
trees_subset = tree_census[['tree_id', 'tree_dbh', 'stump_diam', 'curb_loc', 'status', 'health', 'spc_latin', 'spc_common', 'steward', 'guards', 'sidewalk', 'user_type', 'problems', 'root_stone', 'root_grate', 'root_other', 'trnk_wire', 'trnk_light', 'trnk_other', 'brnch_ligh', 'brnch_shoe', 'brnch_othe']]

# list the first 5 rows of the new subset
trees_subset.head()
# Out:
#    tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0  180,683       3.0         0.0   OnCurb  Alive   Fair
# 1  200,540      21.0         0.0   OnCurb  Alive   Fair
# 2  204,026       3.0         0.0   OnCurb  Alive   Good
# 3  204,337      10.0         0.0   OnCurb  Alive   Good
# 4  189,565      21.0         0.0   OnCurb  Alive   Good
#
#                             spc_latin       spc_common steward guards  ...  \
# 0                         Acer rubrum        red maple     NaN    NaN  ...
# 1                   Quercus palustris          pin oak     NaN    NaN  ...
# 2  Gleditsia triacanthos var. inermis      honeylocust    1or2    NaN  ...
# 3  Gleditsia triacanthos var. inermis      honeylocust     NaN    NaN  ...
# 4                     Tilia americana  American linden     NaN    NaN  ...
#
#   problems root_stone root_grate root_other trnk_wire trnk_light trnk_other  \
# 0      NaN         No         No         No        No         No         No
# 1   Stones        Yes         No         No        No         No         No
# 2      NaN         No         No         No        No         No         No
# 3   Stones        Yes         No         No        No         No         No
# 4   Stones        Yes         No         No        No         No         No
#
#   brnch_ligh brnch_shoe brnch_othe
# 0         No         No         No
# 1         No         No         No
# 2         No         No         No
# 3         No         No         No
# 4         No         No         No
#
# [5 rows x 22 columns]

# %%
# check for any null values
trees_subset.isna().sum()
# Out:
# tree_id            0
# tree_dbh           1
# stump_diam         1
# curb_loc           1
# status             1
# health         19679
# spc_latin      19678
# spc_common     19678
# steward       328844
# guards        379715
# sidewalk       19679
# user_type          1
# problems      292450
# root_stone         1
# root_grate         1
# root_other         1
# trnk_wire          1
# trnk_light         1
# trnk_other         1
# brnch_ligh         1
# brnch_shoe         1
# brnch_othe         1
# dtype: int64

# %%
# show all that are none values in health, alot of missing values NaN
tree_census.describe()
# Out:
#             tree_dbh     stump_diam        zipcode         cb_num  \
# count  424040.000000  424040.000000  424040.000000  424040.000000
# mean       11.230907       0.447998   10859.752276     348.213308
# std         8.780768       3.369355     653.351630     118.433465
# min         0.000000       0.000000      83.000000     101.000000
# 25%         4.000000       0.000000   10314.000000     302.000000
# 50%         9.000000       0.000000   11206.000000     402.000000
# 75%        16.000000       0.000000   11361.000000     413.000000
# max       450.000000     140.000000   11697.000000     503.000000
#
#             borocode       cncldist       st_assem      st_senate  \
# count  424040.000000  424040.000000  424040.000000  424040.000000
# mean        3.407388      30.826983      52.990027      21.307167
# std         1.197049      14.815647      19.157458       7.521407
# min         1.000000       1.000000      23.000000      10.000000
# 25%         3.000000      19.000000      33.000000      15.000000
# 50%         4.000000      30.000000      57.000000      22.000000
# 75%         4.000000      46.000000      64.000000      25.000000
# max         5.000000      51.000000      87.000000      36.000000
#
#             boro_ct       Latitude      longitude
# count  4.240400e+05  424040.000000  424040.000000
# mean   3.453226e+06      40.697706     -73.933415
# std    1.202880e+06       0.097918       0.133710
# min    1.000201e+06      40.498466     -74.254965
# 25%    3.005900e+06      40.620618     -73.991557
# 50%    4.014201e+06      40.693211     -73.914360
# 75%    4.134100e+06      40.765503     -73.842841
# max    5.032300e+06      40.912807     -73.700488

# %%
# generate histogram of data distribution
trees_subset.hist(bins=60, figsize=(20,20))
# Out:
# array([[<Axes: title={'center': 'tree_dbh'}>,
#         <Axes: title={'center': 'stump_diam'}>]], dtype=object)

# %%
# trees larger than 50
big_trees = trees_subset[trees_subset['tree_dbh']> 50]
big_trees.head
# Out:
# <bound method NDFrame.head of         tree_id  tree_dbh  stump_diam        curb_loc status health  \
# 2385    168,583     425.0         0.0          OnCurb  Alive   Good
# 3724    199,546      51.0         0.0          OnCurb  Alive   Good
# 4874    139,665      72.0         0.0  OffsetFromCurb  Alive   Good
# 6711    209,349     122.0         0.0          OnCurb  Alive   Good
# 10053   215,075     169.0         0.0          OnCurb  Alive   Good
# ...         ...       ...         ...             ...    ...    ...
# 408798  627,174      51.0         0.0          OnCurb  Alive   Good
# 417785  587,897      55.0         0.0          OnCurb  Alive   Good
# 418476  638,512      63.0         0.0          OnCurb  Alive   Good
# 418714  626,987      53.0         0.0          OnCurb  Alive   Good
# 423021  647,580      66.0         0.0          OnCurb  Alive   Good
#
#                                  spc_latin        spc_common steward guards  \
# 2385                       Quercus bicolor   swamp white oak    1or2    NaN
# 3724                      Acer saccharinum      silver maple     NaN    NaN
# 4874                      Acer saccharinum      silver maple     NaN    NaN
# 6711                     Quercus palustris           pin oak     NaN    NaN
# 10053   Gleditsia triacanthos var. inermis       honeylocust     NaN    NaN
# ...                                    ...               ...     ...    ...
# 408798                       Quercus rubra  northern red oak     NaN    NaN
# 417785                Robinia pseudoacacia      black locust     NaN    NaN
# 418476               Platanus x acerifolia  London planetree     NaN    NaN
# 418714               Platanus x acerifolia  London planetree     NaN    NaN
# 423021                   Quercus palustris           pin oak     NaN    NaN
#
#         ...   problems root_stone root_grate root_other trnk_wire trnk_light  \
# 2385    ...        NaN         No         No         No        No         No
# 3724    ...     Stones        Yes         No         No        No         No
# 4874    ...        NaN         No         No         No        No         No
# 6711    ...        NaN         No         No         No        No         No
# 10053   ...        NaN         No         No         No        No         No
# ...     ...        ...        ...        ...        ...       ...        ...
# 408798  ...  RootOther         No         No        Yes        No         No
# 417785  ...        NaN         No         No         No        No         No
# 418476  ...        NaN         No         No         No        No         No
# 418714  ...     Stones        Yes         No         No        No         No
# 423021  ...     Stones        Yes         No         No        No         No
#
#        trnk_other brnch_ligh brnch_shoe brnch_othe
# 2385           No         No         No         No
# 3724           No         No         No         No
# 4874           No         No         No         No
# 6711           No         No         No         No
# 10053          No         No         No         No
# ...           ...        ...        ...        ...
# 408798         No         No         No         No
# 417785         No         No         No         No
# 418476         No         No         No         No
# 418714         No         No         No         No
# 423021         No         No         No         No
#
# [240 rows x 22 columns]>

# %%
# box plot
tree_census.boxplot(column='tree_dbh', by='stump_diam')
# Out:
# <Axes: title={'center': 'tree_dbh'}, xlabel='stump_diam'>

# %%
# scatter plot
big_trees[['tree_id', 'tree_dbh']].plot(kind='scatter',x='tree_id', y='tree_dbh')
# Out:
# <Axes: xlabel='tree_id', ylabel='tree_dbh'>
